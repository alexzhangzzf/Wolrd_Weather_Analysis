# %%
#Import the dependencies
import pandas as pd
import numpy as np
from citipy import citipy 
import requests
from config import weather_api_key
import time

# %%
#create a set of random latitude and longitutde combinations
lats =np.random.uniform(low=-90, high=90, size =2000)
lngs =np.random.uniform(low=-180, high=180, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# create a list to hold the cities
cities =[]
# get the nearest city for each lats and lngs using citipy
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    #if the city is unique, add it to the cities list
    if city not in cities:
        cities.append(city)

#print the city count to confirm sufficient count
len(cities)
# Out:
# 768

# %%
#starting URL for weather map API call
base_url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial"

# %%
#creat an empty list to hold the weather data
city_data= []
#print the beginning of the logging
print('Beginning Data Retrieval     ')
print('-----------------------------')

# Create counters
record_count = 1
set_count =1

#loop through all the cities in the list
for i, city in enumerate(cities):
    
    #group cities in sets of 50 for logging purposes
    if (i%50 == 0 and i >= 50):
        set_count+=1
        record_count =1
        time.sleep(60)
        
    # Create endpoint URL with each city
    city_url = base_url + "&q=" + city + "&appid=" + weather_api_key
    
    # log the url, record and set numbers and the city
    print(f"Processing Record{record_count} of Set {set_count} | {city}")
    #add 1 to the recocred count
    record_count+=1
    
# Run an API request for each city
    try:
        # parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        # parse the needed data
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_description = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        
        #append the city information into city_data list
        city_data.append({"City": city.title(),
                          "Country":city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":city_description})

# If an error is experiences, skip the city
    except:
        print('City not found. Skipping...')
        pass
    
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record1 of Set 1 | riacho de santana
# Processing Record2 of Set 1 | bol
# Processing Record3 of Set 1 | saint-philippe
# Processing Record4 of Set 1 | dingle
# Processing Record5 of Set 1 | kaniama
# Processing Record6 of Set 1 | chokurdakh
# Processing Record7 of Set 1 | ancud
# Processing Record8 of Set 1 | ushuaia
# Processing Record9 of Set 1 | laguna
# Processing Record10 of Set 1 | kavieng
# Processing Record11 of Set 1 | grand gaube
# Processing Record12 of Set 1 | touros
# Processing Record13 of Set 1 | xambioa
# Processing Record14 of Set 1 | bathsheba
# Processing Record15 of Set 1 | muzhi
# Processing Record16 of Set 1 | tabas
# Processing Record17 of Set 1 | high level
# Processing Record18 of Set 1 | bambous virieux
# Processing Record19 of Set 1 | thompson
# Processing Record20 of Set 1 | rocha
# Processing Record21 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record22 of Set 1 | georgetown
# Processing Record23 of Set 1 | mataura
# Processing Record24 of Set 1 | obodivka
# Processing Record25 of Set 1 | charters towers
# Processing Record26 of Set 1 | hihifo
# City not found. Skipping...
# Processing Record27 of Set 1 | port alfred
# Processing Record28 of Set 1 | leningradskiy
# Processing Record29 of Set 1 | wladyslawowo
# Processing Record30 of Set 1 | bluff
# Processing Record31 of Set 1 | punta arenas
# Processing Record32 of Set 1 | kapaa
# Processing Record33 of Set 1 | keflavik
# Processing Record34 of Set 1 | buraydah
# Processing Record35 of Set 1 | baijiantan
# Processing Record36 of Set 1 | castro
# Processing Record37 of Set 1 | vila velha
# Processing Record38 of Set 1 | tautira
# Processing Record39 of Set 1 | dikson
# Processing Record40 of Set 1 | kudahuvadhoo
# Processing Record41 of Set 1 | cidreira
# Processing Record42 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record43 of Set 1 | airai
# Processing Record44 of Set 1 | derzhavinsk
# Processing Record45 of Set 1 | amderma
# City not found. Skipping...
# Processing Record46 of Set 1 | iqaluit
# Processing Record47 of Set 1 | luxor
# Processing Record48 of Set 1 | namibe
# Processing Record49 of Set 1 | sarakhs
# Processing Record50 of Set 1 | vaini
# Processing Record1 of Set 2 | ribeira grande
# Processing Record2 of Set 2 | camana
# Processing Record3 of Set 2 | ust-nera
# Processing Record4 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record5 of Set 2 | santiago
# Processing Record6 of Set 2 | zhigansk
# Processing Record7 of Set 2 | kutum
# Processing Record8 of Set 2 | rikitea
# Processing Record9 of Set 2 | mar del plata
# Processing Record10 of Set 2 | jamestown
# Processing Record11 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record12 of Set 2 | arman
# Processing Record13 of Set 2 | inirida
# Processing Record14 of Set 2 | puerto ayora
# Processing Record15 of Set 2 | pevek
# Processing Record16 of Set 2 | cabo san lucas
# Processing Record17 of Set 2 | wichita falls
# Processing Record18 of Set 2 | torbay
# Processing Record19 of Set 2 | hithadhoo
# Processing Record20 of Set 2 | kuhestan
# City not found. Skipping...
# Processing Record21 of Set 2 | ballitoville
# Processing Record22 of Set 2 | bredasdorp
# Processing Record23 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record24 of Set 2 | mount gambier
# Processing Record25 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record26 of Set 2 | mareeba
# Processing Record27 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record28 of Set 2 | comodoro rivadavia
# Processing Record29 of Set 2 | shenjiamen
# Processing Record30 of Set 2 | yellowknife
# Processing Record31 of Set 2 | kloulklubed
# Processing Record32 of Set 2 | port blair
# Processing Record33 of Set 2 | cape town
# Processing Record34 of Set 2 | oktyabrskiy
# Processing Record35 of Set 2 | kahului
# Processing Record36 of Set 2 | iquitos
# Processing Record37 of Set 2 | east london
# Processing Record38 of Set 2 | longyearbyen
# Processing Record39 of Set 2 | solnechnyy
# Processing Record40 of Set 2 | aklavik
# Processing Record41 of Set 2 | gornopravdinsk
# Processing Record42 of Set 2 | vilhena
# Processing Record43 of Set 2 | xiaoweizhai
# Processing Record44 of Set 2 | oistins
# Processing Record45 of Set 2 | yirol
# City not found. Skipping...
# Processing Record46 of Set 2 | jalingo
# Processing Record47 of Set 2 | itoman
# Processing Record48 of Set 2 | palmer
# Processing Record49 of Set 2 | kangaatsiaq
# Processing Record50 of Set 2 | skjervoy
# Processing Record1 of Set 3 | anar darreh
# City not found. Skipping...
# Processing Record2 of Set 3 | cherskiy
# Processing Record3 of Set 3 | safaga
# Processing Record4 of Set 3 | norman wells
# Processing Record5 of Set 3 | samusu
# City not found. Skipping...
# Processing Record6 of Set 3 | hede
# Processing Record7 of Set 3 | hermanus
# Processing Record8 of Set 3 | teneguiban
# City not found. Skipping...
# Processing Record9 of Set 3 | fukue
# Processing Record10 of Set 3 | severo-kurilsk
# Processing Record11 of Set 3 | zhezkazgan
# Processing Record12 of Set 3 | corn island
# Processing Record13 of Set 3 | tasiilaq
# Processing Record14 of Set 3 | hobart
# Processing Record15 of Set 3 | tilichiki
# Processing Record16 of Set 3 | kruisfontein
# Processing Record17 of Set 3 | busselton
# Processing Record18 of Set 3 | nikolskoye
# Processing Record19 of Set 3 | trinidad
# Processing Record20 of Set 3 | la baule-escoublac
# Processing Record21 of Set 3 | te anau
# Processing Record22 of Set 3 | san cristobal
# Processing Record23 of Set 3 | avarua
# Processing Record24 of Set 3 | inhambane
# Processing Record25 of Set 3 | wuwei
# Processing Record26 of Set 3 | la tuque
# Processing Record27 of Set 3 | port hardy
# Processing Record28 of Set 3 | goderich
# Processing Record29 of Set 3 | winnemucca
# Processing Record30 of Set 3 | atuona
# Processing Record31 of Set 3 | jalu
# Processing Record32 of Set 3 | rio de janeiro
# Processing Record33 of Set 3 | hami
# Processing Record34 of Set 3 | ucluelet
# Processing Record35 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record36 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record37 of Set 3 | saint-augustin
# Processing Record38 of Set 3 | saldanha
# Processing Record39 of Set 3 | albany
# Processing Record40 of Set 3 | tibati
# Processing Record41 of Set 3 | quelimane
# Processing Record42 of Set 3 | mallapuram
# Processing Record43 of Set 3 | lagoa
# Processing Record44 of Set 3 | provideniya
# Processing Record45 of Set 3 | zlobin
# Processing Record46 of Set 3 | kodiak
# Processing Record47 of Set 3 | saskylakh
# Processing Record48 of Set 3 | mariental
# Processing Record49 of Set 3 | general pico
# Processing Record50 of Set 3 | hasaki
# Processing Record1 of Set 4 | upernavik
# Processing Record2 of Set 4 | didsbury
# Processing Record3 of Set 4 | tarakan
# Processing Record4 of Set 4 | bayan
# Processing Record5 of Set 4 | alihe
# Processing Record6 of Set 4 | brownwood
# Processing Record7 of Set 4 | codrington
# Processing Record8 of Set 4 | havelock
# Processing Record9 of Set 4 | lebu
# Processing Record10 of Set 4 | bam
# Processing Record11 of Set 4 | dolores
# Processing Record12 of Set 4 | victoria
# Processing Record13 of Set 4 | karancskeszi
# Processing Record14 of Set 4 | eyl
# Processing Record15 of Set 4 | ilulissat
# Processing Record16 of Set 4 | lazaro cardenas
# Processing Record17 of Set 4 | padang
# Processing Record18 of Set 4 | najran
# Processing Record19 of Set 4 | new norfolk
# Processing Record20 of Set 4 | aasiaat
# Processing Record21 of Set 4 | saint george
# Processing Record22 of Set 4 | wahiawa
# Processing Record23 of Set 4 | slave lake
# Processing Record24 of Set 4 | lompoc
# Processing Record25 of Set 4 | konstantinovka
# Processing Record26 of Set 4 | hilo
# Processing Record27 of Set 4 | kattivakkam
# Processing Record28 of Set 4 | virtsu
# Processing Record29 of Set 4 | karratha
# Processing Record30 of Set 4 | high river
# Processing Record31 of Set 4 | urfa
# City not found. Skipping...
# Processing Record32 of Set 4 | namatanai
# Processing Record33 of Set 4 | khatanga
# Processing Record34 of Set 4 | butaritari
# Processing Record35 of Set 4 | shirokiy
# Processing Record36 of Set 4 | bahia honda
# Processing Record37 of Set 4 | arys
# Processing Record38 of Set 4 | banjar
# Processing Record39 of Set 4 | tuktoyaktuk
# Processing Record40 of Set 4 | barrow
# Processing Record41 of Set 4 | margate
# Processing Record42 of Set 4 | brufut
# Processing Record43 of Set 4 | bardiyah
# Processing Record44 of Set 4 | salinas
# Processing Record45 of Set 4 | trairi
# Processing Record46 of Set 4 | tuatapere
# Processing Record47 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record48 of Set 4 | icatu
# Processing Record49 of Set 4 | deoria
# Processing Record50 of Set 4 | san patricio
# Processing Record1 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record2 of Set 5 | uarini
# Processing Record3 of Set 5 | porto novo
# Processing Record4 of Set 5 | amapa
# Processing Record5 of Set 5 | saint-joseph
# Processing Record6 of Set 5 | grootfontein
# Processing Record7 of Set 5 | mehamn
# Processing Record8 of Set 5 | tiksi
# Processing Record9 of Set 5 | andrews
# Processing Record10 of Set 5 | tabou
# Processing Record11 of Set 5 | mahebourg
# Processing Record12 of Set 5 | narsaq
# Processing Record13 of Set 5 | nuevo progreso
# Processing Record14 of Set 5 | llanes
# Processing Record15 of Set 5 | kaitangata
# Processing Record16 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record17 of Set 5 | saquarema
# Processing Record18 of Set 5 | huilong
# Processing Record19 of Set 5 | villa maria
# Processing Record20 of Set 5 | kropotkin
# Processing Record21 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record22 of Set 5 | emerald
# Processing Record23 of Set 5 | broken hill
# Processing Record24 of Set 5 | albanel
# Processing Record25 of Set 5 | den helder
# Processing Record26 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record27 of Set 5 | carman
# Processing Record28 of Set 5 | sorata
# Processing Record29 of Set 5 | yabelo
# Processing Record30 of Set 5 | colares
# Processing Record31 of Set 5 | bengkulu
# Processing Record32 of Set 5 | takoradi
# Processing Record33 of Set 5 | salalah
# Processing Record34 of Set 5 | bambanglipuro
# Processing Record35 of Set 5 | miracema do tocantins
# Processing Record36 of Set 5 | chuy
# Processing Record37 of Set 5 | acapulco
# Processing Record38 of Set 5 | olafsvik
# Processing Record39 of Set 5 | paamiut
# Processing Record40 of Set 5 | sao joao da barra
# Processing Record41 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record42 of Set 5 | spirit river
# Processing Record43 of Set 5 | hambantota
# Processing Record44 of Set 5 | dubai
# Processing Record45 of Set 5 | skibbereen
# Processing Record46 of Set 5 | loa janan
# Processing Record47 of Set 5 | arraial do cabo
# Processing Record48 of Set 5 | whitianga
# Processing Record49 of Set 5 | lorengau
# Processing Record50 of Set 5 | jinchang
# Processing Record1 of Set 6 | inuvik
# Processing Record2 of Set 6 | sainte-anne-des-monts
# Processing Record3 of Set 6 | birjand
# Processing Record4 of Set 6 | vanimo
# Processing Record5 of Set 6 | coquimbo
# Processing Record6 of Set 6 | kaputa
# Processing Record7 of Set 6 | floro
# Processing Record8 of Set 6 | jaora
# Processing Record9 of Set 6 | vestmanna
# Processing Record10 of Set 6 | kavaratti
# Processing Record11 of Set 6 | bethel
# Processing Record12 of Set 6 | pacific grove
# Processing Record13 of Set 6 | alugan
# Processing Record14 of Set 6 | nanortalik
# Processing Record15 of Set 6 | libreville
# Processing Record16 of Set 6 | tura
# Processing Record17 of Set 6 | kamenka
# Processing Record18 of Set 6 | okhotsk
# Processing Record19 of Set 6 | mizpe ramon
# City not found. Skipping...
# Processing Record20 of Set 6 | muros
# Processing Record21 of Set 6 | qaanaaq
# Processing Record22 of Set 6 | vitim
# Processing Record23 of Set 6 | tateyama
# Processing Record24 of Set 6 | newport
# Processing Record25 of Set 6 | catamarca
# Processing Record26 of Set 6 | ust-kuyga
# Processing Record27 of Set 6 | cravo norte
# Processing Record28 of Set 6 | yerbogachen
# Processing Record29 of Set 6 | fevralsk
# City not found. Skipping...
# Processing Record30 of Set 6 | la ronge
# Processing Record31 of Set 6 | ardmore
# Processing Record32 of Set 6 | aitape
# Processing Record33 of Set 6 | clyde river
# Processing Record34 of Set 6 | maungaturoto
# Processing Record35 of Set 6 | urumqi
# Processing Record36 of Set 6 | vila
# Processing Record37 of Set 6 | carnarvon
# Processing Record38 of Set 6 | tawnat
# City not found. Skipping...
# Processing Record39 of Set 6 | lyngseidet
# Processing Record40 of Set 6 | kieta
# Processing Record41 of Set 6 | saint anthony
# Processing Record42 of Set 6 | port elizabeth
# Processing Record43 of Set 6 | novikovo
# Processing Record44 of Set 6 | malakal
# Processing Record45 of Set 6 | hovd
# Processing Record46 of Set 6 | moussoro
# Processing Record47 of Set 6 | qingdao
# Processing Record48 of Set 6 | vardo
# Processing Record49 of Set 6 | sitka
# Processing Record50 of Set 6 | oyotun
# Processing Record1 of Set 7 | ulundi
# Processing Record2 of Set 7 | plettenberg bay
# Processing Record3 of Set 7 | beringovskiy
# Processing Record4 of Set 7 | geraldton
# Processing Record5 of Set 7 | kendari
# Processing Record6 of Set 7 | mentok
# City not found. Skipping...
# Processing Record7 of Set 7 | passo fundo
# Processing Record8 of Set 7 | alofi
# Processing Record9 of Set 7 | lata
# Processing Record10 of Set 7 | manzil jamil
# City not found. Skipping...
# Processing Record11 of Set 7 | labutta
# City not found. Skipping...
# Processing Record12 of Set 7 | butembo
# Processing Record13 of Set 7 | axim
# Processing Record14 of Set 7 | atar
# Processing Record15 of Set 7 | sao filipe
# Processing Record16 of Set 7 | beysehir
# Processing Record17 of Set 7 | lieksa
# Processing Record18 of Set 7 | husavik
# Processing Record19 of Set 7 | carutapera
# Processing Record20 of Set 7 | russell
# Processing Record21 of Set 7 | necochea
# Processing Record22 of Set 7 | ostersund
# Processing Record23 of Set 7 | rameswaram
# Processing Record24 of Set 7 | khuzhir
# Processing Record25 of Set 7 | cabra
# Processing Record26 of Set 7 | montorio al vomano
# Processing Record27 of Set 7 | gat
# Processing Record28 of Set 7 | ugoofaaru
# Processing Record29 of Set 7 | san antonio
# Processing Record30 of Set 7 | minab
# Processing Record31 of Set 7 | fortuna
# Processing Record32 of Set 7 | oneonta
# Processing Record33 of Set 7 | tamworth
# Processing Record34 of Set 7 | talnakh
# Processing Record35 of Set 7 | turinsk
# Processing Record36 of Set 7 | boulder
# Processing Record37 of Set 7 | denizli
# Processing Record38 of Set 7 | makakilo city
# Processing Record39 of Set 7 | hamilton
# Processing Record40 of Set 7 | baykit
# Processing Record41 of Set 7 | deputatskiy
# Processing Record42 of Set 7 | shingu
# Processing Record43 of Set 7 | klyuchi
# Processing Record44 of Set 7 | cabedelo
# Processing Record45 of Set 7 | pantai remis
# Processing Record46 of Set 7 | pimampiro
# Processing Record47 of Set 7 | tongchuan
# Processing Record48 of Set 7 | bud
# Processing Record49 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record50 of Set 7 | flinders
# Processing Record1 of Set 8 | mayumba
# Processing Record2 of Set 8 | yanchukan
# City not found. Skipping...
# Processing Record3 of Set 8 | stonewall
# Processing Record4 of Set 8 | behbahan
# Processing Record5 of Set 8 | bonavista
# Processing Record6 of Set 8 | rio grande
# Processing Record7 of Set 8 | dinsor
# City not found. Skipping...
# Processing Record8 of Set 8 | gobabis
# Processing Record9 of Set 8 | egvekinot
# Processing Record10 of Set 8 | san pedro de ycuamandiyu
# Processing Record11 of Set 8 | bitkine
# Processing Record12 of Set 8 | lavrentiya
# Processing Record13 of Set 8 | sokoni
# Processing Record14 of Set 8 | pavlodar
# Processing Record15 of Set 8 | bundaberg
# Processing Record16 of Set 8 | les cayes
# Processing Record17 of Set 8 | oda
# Processing Record18 of Set 8 | goycay
# City not found. Skipping...
# Processing Record19 of Set 8 | bowen
# Processing Record20 of Set 8 | el alto
# Processing Record21 of Set 8 | srednekolymsk
# Processing Record22 of Set 8 | olinda
# Processing Record23 of Set 8 | champerico
# Processing Record24 of Set 8 | whitehorse
# Processing Record25 of Set 8 | waddan
# Processing Record26 of Set 8 | beisfjord
# Processing Record27 of Set 8 | tazovskiy
# Processing Record28 of Set 8 | prince george
# Processing Record29 of Set 8 | sakakah
# Processing Record30 of Set 8 | manavgat
# Processing Record31 of Set 8 | alice springs
# Processing Record32 of Set 8 | misratah
# Processing Record33 of Set 8 | angoche
# Processing Record34 of Set 8 | coahuayana
# Processing Record35 of Set 8 | faanui
# Processing Record36 of Set 8 | iralaya
# Processing Record37 of Set 8 | ruatoria
# City not found. Skipping...
# Processing Record38 of Set 8 | duma
# Processing Record39 of Set 8 | faya
# Processing Record40 of Set 8 | tamiahua
# Processing Record41 of Set 8 | ballina
# Processing Record42 of Set 8 | kondopoga
# Processing Record43 of Set 8 | katsuura
# Processing Record44 of Set 8 | cosala
# Processing Record45 of Set 8 | khorramshahr
# Processing Record46 of Set 8 | barawe
# City not found. Skipping...
# Processing Record47 of Set 8 | northam
# Processing Record48 of Set 8 | shimoda
# Processing Record49 of Set 8 | ngukurr
# City not found. Skipping...
# Processing Record50 of Set 8 | seda
# Processing Record1 of Set 9 | dzhusaly
# City not found. Skipping...
# Processing Record2 of Set 9 | henties bay
# Processing Record3 of Set 9 | yulara
# Processing Record4 of Set 9 | tottori
# Processing Record5 of Set 9 | port keats
# Processing Record6 of Set 9 | burica
# City not found. Skipping...
# Processing Record7 of Set 9 | ixtapa
# Processing Record8 of Set 9 | gander
# Processing Record9 of Set 9 | trincomalee
# Processing Record10 of Set 9 | sal rei
# Processing Record11 of Set 9 | sao miguel do oeste
# City not found. Skipping...
# Processing Record12 of Set 9 | atikokan
# Processing Record13 of Set 9 | horodnytsya
# Processing Record14 of Set 9 | clarence town
# Processing Record15 of Set 9 | marfino
# Processing Record16 of Set 9 | ambilobe
# Processing Record17 of Set 9 | cairns
# Processing Record18 of Set 9 | sorland
# Processing Record19 of Set 9 | mocuba
# Processing Record20 of Set 9 | esperance
# Processing Record21 of Set 9 | klaksvik
# Processing Record22 of Set 9 | masterton
# Processing Record23 of Set 9 | islamkot
# Processing Record24 of Set 9 | grindavik
# Processing Record25 of Set 9 | college
# Processing Record26 of Set 9 | kazalinsk
# City not found. Skipping...
# Processing Record27 of Set 9 | marzuq
# Processing Record28 of Set 9 | auki
# Processing Record29 of Set 9 | rawannawi
# City not found. Skipping...
# Processing Record30 of Set 9 | caravelas
# Processing Record31 of Set 9 | aktas
# Processing Record32 of Set 9 | union
# Processing Record33 of Set 9 | komsomolskiy
# Processing Record34 of Set 9 | sengiley
# Processing Record35 of Set 9 | maniitsoq
# Processing Record36 of Set 9 | bargal
# City not found. Skipping...
# Processing Record37 of Set 9 | souillac
# Processing Record38 of Set 9 | hereford
# Processing Record39 of Set 9 | lixourion
# Processing Record40 of Set 9 | trofors
# Processing Record41 of Set 9 | kanigoro
# Processing Record42 of Set 9 | luderitz
# Processing Record43 of Set 9 | puerto madryn
# Processing Record44 of Set 9 | karauzyak
# City not found. Skipping...
# Processing Record45 of Set 9 | bertoua
# Processing Record46 of Set 9 | nsanje
# Processing Record47 of Set 9 | horta
# Processing Record48 of Set 9 | samarai
# Processing Record49 of Set 9 | padre bernardo
# Processing Record50 of Set 9 | ergani
# Processing Record1 of Set 10 | talca
# Processing Record2 of Set 10 | ahipara
# Processing Record3 of Set 10 | havoysund
# Processing Record4 of Set 10 | berlevag
# Processing Record5 of Set 10 | labuhan
# Processing Record6 of Set 10 | akdepe
# Processing Record7 of Set 10 | lunderskov
# Processing Record8 of Set 10 | tsienyane
# City not found. Skipping...
# Processing Record9 of Set 10 | portland
# Processing Record10 of Set 10 | camargo
# Processing Record11 of Set 10 | macamic
# Processing Record12 of Set 10 | mahibadhoo
# Processing Record13 of Set 10 | severomorsk
# Processing Record14 of Set 10 | tommot
# Processing Record15 of Set 10 | dubbo
# Processing Record16 of Set 10 | yuzhno-kurilsk
# Processing Record17 of Set 10 | adrar
# Processing Record18 of Set 10 | boca do acre
# Processing Record19 of Set 10 | chernyshevskiy
# Processing Record20 of Set 10 | tiarei
# Processing Record21 of Set 10 | nabire
# Processing Record22 of Set 10 | ovre ardal
# Processing Record23 of Set 10 | asfi
# Processing Record24 of Set 10 | severo-yeniseyskiy
# Processing Record25 of Set 10 | allanmyo
# City not found. Skipping...
# Processing Record26 of Set 10 | providencia
# Processing Record27 of Set 10 | ouesso
# Processing Record28 of Set 10 | sola
# Processing Record29 of Set 10 | augusto correa
# Processing Record30 of Set 10 | beyneu
# Processing Record31 of Set 10 | horizontina
# Processing Record32 of Set 10 | mackay
# Processing Record33 of Set 10 | baghdad
# Processing Record34 of Set 10 | cacequi
# Processing Record35 of Set 10 | xiongshi
# City not found. Skipping...
# Processing Record36 of Set 10 | walvis bay
# Processing Record37 of Set 10 | russkaya polyana
# Processing Record38 of Set 10 | soe
# Processing Record39 of Set 10 | arakhnaion
# City not found. Skipping...
# Processing Record40 of Set 10 | voyvozh
# Processing Record41 of Set 10 | opunake
# Processing Record42 of Set 10 | homnabad
# Processing Record43 of Set 10 | ouegoa
# Processing Record44 of Set 10 | benjamin hill
# Processing Record45 of Set 10 | lima
# Processing Record46 of Set 10 | hualmay
# Processing Record47 of Set 10 | kembe
# Processing Record48 of Set 10 | logon
# Processing Record49 of Set 10 | suntar
# Processing Record50 of Set 10 | utiroa
# City not found. Skipping...
# Processing Record1 of Set 11 | la palma
# Processing Record2 of Set 11 | pandamatenga
# Processing Record3 of Set 11 | lashio
# Processing Record4 of Set 11 | lufkin
# Processing Record5 of Set 11 | isangel
# Processing Record6 of Set 11 | manokwari
# Processing Record7 of Set 11 | pisco
# Processing Record8 of Set 11 | poya
# Processing Record9 of Set 11 | ponta do sol
# Processing Record10 of Set 11 | kampene
# Processing Record11 of Set 11 | morgan city
# Processing Record12 of Set 11 | daloa
# Processing Record13 of Set 11 | naryan-mar
# Processing Record14 of Set 11 | assela
# City not found. Skipping...
# Processing Record15 of Set 11 | yumen
# Processing Record16 of Set 11 | qaqortoq
# Processing Record17 of Set 11 | seymour
# Processing Record18 of Set 11 | arrifes
# Processing Record19 of Set 11 | fairbanks
# Processing Record20 of Set 11 | quang ngai
# Processing Record21 of Set 11 | pitimbu
# Processing Record22 of Set 11 | abalak
# Processing Record23 of Set 11 | camabatela
# Processing Record24 of Set 11 | raudeberg
# Processing Record25 of Set 11 | warqla
# City not found. Skipping...
# Processing Record26 of Set 11 | saint-pierre
# Processing Record27 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record28 of Set 11 | bilma
# Processing Record29 of Set 11 | juegang
# Processing Record30 of Set 11 | harper
# Processing Record31 of Set 11 | mizdah
# Processing Record32 of Set 11 | dwarka
# Processing Record33 of Set 11 | atherton
# Processing Record34 of Set 11 | puerto del rosario
# Processing Record35 of Set 11 | belaya gora
# Processing Record36 of Set 11 | sisimiut
# Processing Record37 of Set 11 | muriti
# Processing Record38 of Set 11 | malinyi
# Processing Record39 of Set 11 | xinzhi
# Processing Record40 of Set 11 | roald
# Processing Record41 of Set 11 | mazatlan
# Processing Record42 of Set 11 | tinca
# Processing Record43 of Set 11 | korla
# Processing Record44 of Set 11 | nhulunbuy
# Processing Record45 of Set 11 | jacareacanga
# Processing Record46 of Set 11 | karachi
# Processing Record47 of Set 11 | mnogovershinnyy
# Processing Record48 of Set 11 | nouakchott
# Processing Record49 of Set 11 | naze
# Processing Record50 of Set 11 | santiago del estero
# Processing Record1 of Set 12 | waingapu
# Processing Record2 of Set 12 | pilao arcado
# City not found. Skipping...
# Processing Record3 of Set 12 | morden
# Processing Record4 of Set 12 | farah
# Processing Record5 of Set 12 | altamont
# Processing Record6 of Set 12 | ndjole
# Processing Record7 of Set 12 | kuytun
# Processing Record8 of Set 12 | yichang
# Processing Record9 of Set 12 | ahuimanu
# Processing Record10 of Set 12 | price
# Processing Record11 of Set 12 | rawson
# Processing Record12 of Set 12 | fitchburg
# Processing Record13 of Set 12 | pangnirtung
# Processing Record14 of Set 12 | itarema
# Processing Record15 of Set 12 | mandalgovi
# Processing Record16 of Set 12 | brigantine
# Processing Record17 of Set 12 | kalianget
# Processing Record18 of Set 12 | pochutla
# Processing Record19 of Set 12 | solovetskiy
# City not found. Skipping...
# Processing Record20 of Set 12 | sabzevar
# Processing Record21 of Set 12 | cartagena
# Processing Record22 of Set 12 | kununurra
# Processing Record23 of Set 12 | zhangye
# Processing Record24 of Set 12 | tevaitoa
# Processing Record25 of Set 12 | marondera
# Processing Record26 of Set 12 | port lincoln
# Processing Record27 of Set 12 | rayadrug
# Processing Record28 of Set 12 | mao
# Processing Record29 of Set 12 | harindanga
# Processing Record30 of Set 12 | kaeo
# Processing Record31 of Set 12 | pilar
# Processing Record32 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record33 of Set 12 | san carlos
# Processing Record34 of Set 12 | tubruq
# City not found. Skipping...
# Processing Record35 of Set 12 | hofn
# Processing Record36 of Set 12 | santa isabel do rio negro
# Processing Record37 of Set 12 | talaya
# Processing Record38 of Set 12 | terrell
# Processing Record39 of Set 12 | hirara
# Processing Record40 of Set 12 | ust-tsilma
# Processing Record41 of Set 12 | wloszczowa
# Processing Record42 of Set 12 | pervomayskoye
# Processing Record43 of Set 12 | ostrovnoy
# Processing Record44 of Set 12 | arinos
# Processing Record45 of Set 12 | stoyba
# City not found. Skipping...
# Processing Record46 of Set 12 | inderborskiy
# City not found. Skipping...
# Processing Record47 of Set 12 | nioro
# Processing Record48 of Set 12 | dudinka
# Processing Record49 of Set 12 | racovita
# Processing Record50 of Set 12 | sao gabriel da cachoeira
# Processing Record1 of Set 13 | bandarbeyla
# Processing Record2 of Set 13 | turukhansk
# Processing Record3 of Set 13 | nador
# Processing Record4 of Set 13 | the pas
# Processing Record5 of Set 13 | tokuyama
# Processing Record6 of Set 13 | bur gabo
# City not found. Skipping...
# Processing Record7 of Set 13 | port-cartier
# Processing Record8 of Set 13 | erzin
# Processing Record9 of Set 13 | pierre
# Processing Record10 of Set 13 | jambi
# Processing Record11 of Set 13 | payo
# Processing Record12 of Set 13 | zhuhai
# Processing Record13 of Set 13 | male
# Processing Record14 of Set 13 | hudiksvall
# Processing Record15 of Set 13 | kijang
# Processing Record16 of Set 13 | mitzic
# Processing Record17 of Set 13 | gizo
# Processing Record18 of Set 13 | nelson bay
# Processing Record19 of Set 13 | taltal
# Processing Record20 of Set 13 | yushan
# Processing Record21 of Set 13 | virginia beach
# Processing Record22 of Set 13 | dzhebariki-khaya
# Processing Record23 of Set 13 | beziers
# Processing Record24 of Set 13 | christchurch
# Processing Record25 of Set 13 | biak
# Processing Record26 of Set 13 | pemangkat
# Processing Record27 of Set 13 | biloela
# Processing Record28 of Set 13 | opuwo
# Processing Record29 of Set 13 | tukrah
# Processing Record30 of Set 13 | rungata
# City not found. Skipping...
# Processing Record31 of Set 13 | mozarlandia
# Processing Record32 of Set 13 | manta
# Processing Record33 of Set 13 | mayskiy
# Processing Record34 of Set 13 | san andres
# Processing Record35 of Set 13 | sakaide
# Processing Record36 of Set 13 | trabzon
# Processing Record37 of Set 13 | bara
# Processing Record38 of Set 13 | mys shmidta
# City not found. Skipping...
# Processing Record39 of Set 13 | aripuana
# Processing Record40 of Set 13 | yar-sale
# Processing Record41 of Set 13 | immokalee
# Processing Record42 of Set 13 | havre-saint-pierre
# Processing Record43 of Set 13 | sao mateus do sul
# Processing Record44 of Set 13 | tessalit
# Processing Record45 of Set 13 | vanavara
# Processing Record46 of Set 13 | tigil
# Processing Record47 of Set 13 | lizzano
# Processing Record48 of Set 13 | yebaishou
# Processing Record49 of Set 13 | port-gentil
# Processing Record50 of Set 13 | beloha
# Processing Record1 of Set 14 | sonamukhi
# Processing Record2 of Set 14 | mocambique
# City not found. Skipping...
# Processing Record3 of Set 14 | fallon
# Processing Record4 of Set 14 | garowe
# Processing Record5 of Set 14 | vice
# Processing Record6 of Set 14 | tornio
# Processing Record7 of Set 14 | constitucion
# Processing Record8 of Set 14 | caceres
# Processing Record9 of Set 14 | manggar
# Processing Record10 of Set 14 | maryville
# Processing Record11 of Set 14 | kaiserslautern
# Processing Record12 of Set 14 | khani
# Processing Record13 of Set 14 | boguchany
# Processing Record14 of Set 14 | acarau
# Processing Record15 of Set 14 | daru
# Processing Record16 of Set 14 | thinadhoo
# Processing Record17 of Set 14 | alyangula
# Processing Record18 of Set 14 | kodinsk
# Processing Record19 of Set 14 | istmina
# Processing Record20 of Set 14 | nchelenge
# Processing Record21 of Set 14 | hailar
# Processing Record22 of Set 14 | ahmadnagar
# Processing Record23 of Set 14 | guaimaro
# Processing Record24 of Set 14 | guanica
# Processing Record25 of Set 14 | nizhneangarsk
# Processing Record26 of Set 14 | addi ugri
# City not found. Skipping...
# Processing Record27 of Set 14 | concarneau
# Processing Record28 of Set 14 | banda aceh
# Processing Record29 of Set 14 | bastia
# Processing Record30 of Set 14 | kharp
# Processing Record31 of Set 14 | noshiro
# Processing Record32 of Set 14 | gayny
# Processing Record33 of Set 14 | hvammstangi
# City not found. Skipping...
# Processing Record34 of Set 14 | vestmannaeyjar
# Processing Record35 of Set 14 | sibolga
# Processing Record36 of Set 14 | meulaboh
# Processing Record37 of Set 14 | awjilah
# Processing Record38 of Set 14 | muroto
# Processing Record39 of Set 14 | alta floresta
# Processing Record40 of Set 14 | paso de carrasco
# Processing Record41 of Set 14 | umm kaddadah
# Processing Record42 of Set 14 | tawkar
# City not found. Skipping...
# Processing Record43 of Set 14 | mallaig
# Processing Record44 of Set 14 | barbar
# City not found. Skipping...
# Processing Record45 of Set 14 | wanxian
# Processing Record46 of Set 14 | medicine hat
# Processing Record47 of Set 14 | miroslava
# Processing Record48 of Set 14 | kupang
# Processing Record49 of Set 14 | krosno
# Processing Record50 of Set 14 | tambopata
# Processing Record1 of Set 15 | bilibino
# Processing Record2 of Set 15 | barra do garcas
# Processing Record3 of Set 15 | zhaoyuan
# Processing Record4 of Set 15 | orgun
# City not found. Skipping...
# Processing Record5 of Set 15 | xai-xai
# Processing Record6 of Set 15 | scottsburgh
# City not found. Skipping...
# Processing Record7 of Set 15 | tuy hoa
# Processing Record8 of Set 15 | huangmei
# Processing Record9 of Set 15 | port hedland
# Processing Record10 of Set 15 | nyurba
# Processing Record11 of Set 15 | sabya
# Processing Record12 of Set 15 | sinegorye
# Processing Record13 of Set 15 | lukovetskiy
# Processing Record14 of Set 15 | turayf
# Processing Record15 of Set 15 | otradnoye
# Processing Record16 of Set 15 | verkhnyaya inta
# Processing Record17 of Set 15 | half moon bay
# Processing Record18 of Set 15 | borlange
# City not found. Skipping...
# Processing Record19 of Set 15 | humaita
# Processing Record20 of Set 15 | asau
# Processing Record21 of Set 15 | mubarakpur
# Processing Record22 of Set 15 | hannibal
# Processing Record23 of Set 15 | xichang
# Processing Record24 of Set 15 | bodden town
# Processing Record25 of Set 15 | mount isa
# Processing Record26 of Set 15 | satitoa
# City not found. Skipping...
# Processing Record27 of Set 15 | xining
# Processing Record28 of Set 15 | zirovnice
# Processing Record29 of Set 15 | camacha
# Processing Record30 of Set 15 | tongzi
# Processing Record31 of Set 15 | miraflores
# Processing Record32 of Set 15 | berbera
# Processing Record33 of Set 15 | fare
# Processing Record34 of Set 15 | sulangan
# Processing Record35 of Set 15 | rubtsovsk
# Processing Record36 of Set 15 | balkhash
# Processing Record37 of Set 15 | santa cruz de tenerife
# Processing Record38 of Set 15 | jinxiang
# Processing Record39 of Set 15 | panino
# Processing Record40 of Set 15 | mbaiki
# Processing Record41 of Set 15 | cartago
# Processing Record42 of Set 15 | bougouni
# Processing Record43 of Set 15 | fort nelson
# Processing Record44 of Set 15 | never
# Processing Record45 of Set 15 | poum
# Processing Record46 of Set 15 | boa vista
# Processing Record47 of Set 15 | seydi
# Processing Record48 of Set 15 | sur
# Processing Record49 of Set 15 | dembi dolo
# Processing Record50 of Set 15 | north bend
# Processing Record1 of Set 16 | nicoya
# Processing Record2 of Set 16 | rio gallegos
# Processing Record3 of Set 16 | hit
# Processing Record4 of Set 16 | noyabrsk
# Processing Record5 of Set 16 | evensk
# Processing Record6 of Set 16 | orange cove
# Processing Record7 of Set 16 | envira
# Processing Record8 of Set 16 | monte carmelo
# Processing Record9 of Set 16 | krasnyy kut
# Processing Record10 of Set 16 | dunkirk
# Processing Record11 of Set 16 | brainerd
# Processing Record12 of Set 16 | brae
# Processing Record13 of Set 16 | mier
# Processing Record14 of Set 16 | keffi
# Processing Record15 of Set 16 | bereda
# Processing Record16 of Set 16 | chicama
# Processing Record17 of Set 16 | shaartuz
# City not found. Skipping...
# Processing Record18 of Set 16 | south lake tahoe
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#convert the array of dictionaries to a pandas dataframe
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#                   City Country      Lat       Lng  Max Temp  Humidity  \
# 0    Riacho De Santana      BR -13.6092  -42.9389     72.36        88
# 1                  Bol      TD  13.4586   14.7147     72.82        34
# 2       Saint-Philippe      RE -21.3585   55.7679     78.39        80
# 3               Dingle      PH  10.9995  122.6711     73.38        89
# 4              Kaniama      CD  -7.5667   24.1833     66.49        96
# ..                 ...     ...      ...       ...       ...       ...
# 694               Mier      MX  26.4333  -99.1500     65.08        37
# 695              Keffi      NG   8.8486    7.8736     82.31        15
# 696             Bereda      ES  43.2686   -7.5406     48.92        98
# 697            Chicama      PE  -7.8447  -79.1469     70.34        57
# 698   South Lake Tahoe      US  38.9332 -119.9844     51.35        35
#
#      Cloudiness  Wind Speed Current Description
# 0           100        3.69       moderate rain
# 1             0       15.66           clear sky
# 2            99       15.50     overcast clouds
# 3            63        8.48       broken clouds
# 4           100        4.05          light rain
# ..          ...         ...                 ...
# 694           1        8.03           clear sky
# 695          31        2.95    scattered clouds
# 696          78        2.86       broken clouds
# 697          88       11.72     overcast clouds
# 698           0        0.00           clear sky
#
# [699 rows x 9 columns]

# %%
# Create the output file(CSV) 
output_data_file = "WeatherPy_Database.csv"
#export the city_data into a csv
city_data_df.to_csv(output_data_file, index_label="City_ID")
